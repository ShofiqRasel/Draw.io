# %% [markdown]
# <a href="https://colab.research.google.com/github/ShofiqRasel/Draw.io/blob/main/ClassOn03_07_2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
text = "python"
print(text[:-1])
# Out:
# pytho

# %%
text = "python"
print(text[::-1])
# Out:
# nohtyp

# %%
text = "python"
print(text[-1:])
# Out:
# n

# %%
Text = "29"
print (type(Text))
# Out:
# <class 'str'>

# %%
Value = 29
print (f"The value 29 is now {type(Value)} Now I convert it into String  {str(Value)} {type(Value)}")
# Out:
# The value 29 is now <class 'int'> Now I convert it into String  29 <class 'int'>

# %%
from datetime import datetime as dt
now = dt.now()
NewDate = now.strftime("%d-%m-%Y")
#print (now)
print (NewDate)
# Out:
# 12-07-2026
